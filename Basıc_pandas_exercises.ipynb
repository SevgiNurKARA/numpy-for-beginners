# %%
import pandas as pd

# %%
movies=pd.read_csv("100 Best Movies on Netflix.csv")

# %%
movies
# Out:
#     Rank                      Movie Title  Year  Score             Director  \
# 0      1                        His House  2020    100          Remi Weekes
# 1      2         How to Train Your Dragon  2010     99  Christopher Sanders
# 2      3       The Forty-Year-Old Version  2020     99          Radha Blank
# 3      4                 Under the Shadow  2016     99         Babak Anvari
# 4      5  Monty Python and the Holy Grail  1975     98        Terry Gilliam
# ..   ...                              ...   ...    ...                  ...
# 95    96     Fear Street Part Three: 1666  2021     88         Leigh Janiak
# 96    97                    Donnie Brasco  1997     88          Mike Newell
# 97    98                        Inception  2010     87    Christopher Nolan
# 98    99                  American Beauty  1999     87           Sam Mendes
# 99   100                    Kung Fu Panda  2008     87       John Stevenson
#
#                                                  Cast  \
# ...

# %%
movies.head()
# Out:
#    Rank                      Movie Title  Year  Score             Director  \
# 0     1                        His House  2020    100          Remi Weekes
# 1     2         How to Train Your Dragon  2010     99  Christopher Sanders
# 2     3       The Forty-Year-Old Version  2020     99          Radha Blank
# 3     4                 Under the Shadow  2016     99         Babak Anvari
# 4     5  Monty Python and the Holy Grail  1975     98        Terry Gilliam
#
#                                                 Cast  \
# 0  Wunmi Mosaku, Sope Dirisu, Matt Smith, Cornell...
# 1  Jay Baruchel, Gerard Butler, America Ferrera, ...
# 2  Welker White, Reed Birney, Radha Blank, Peter Kim
# 3  Narges Rashidi, Avin Manshadi, Bobby Naderi, R...
# 4  Graham Chapman, John Cleese, Terry Gilliam, Er...
#
#                                    Critics Consensus
# 0  Featuring genuine scares through every corrido...
# 1  Boasting dazzling animation, a script with sur...
# ...

# %%
movies.head(10)
# Out:
#    Rank                      Movie Title  Year  Score             Director  \
# 0     1                        His House  2020    100          Remi Weekes
# 1     2         How to Train Your Dragon  2010     99  Christopher Sanders
# 2     3       The Forty-Year-Old Version  2020     99          Radha Blank
# 3     4                 Under the Shadow  2016     99         Babak Anvari
# 4     5  Monty Python and the Holy Grail  1975     98        Terry Gilliam
# 5     6         Ma Rainey's Black Bottom  2020     97      George C. Wolfe
# 6     7                  The Hurt Locker  2008     97      Kathryn Bigelow
# 7     8               Hell or High Water  2016     97      David Mackenzie
# 8     9        Won't You Be My Neighbor?  2018     97       Morgan Neville
# 9    10              Dolemite Is My Name  2019     97         Craig Brewer
#
#                                                 Cast  \
# 0  Wunmi Mosaku, Sope Dirisu, Matt Smith, Cornell...
# ...

# %%
movies.tail()
# Out:
#     Rank                   Movie Title  Year  Score           Director  \
# 95    96  Fear Street Part Three: 1666  2021     88       Leigh Janiak
# 96    97                 Donnie Brasco  1997     88        Mike Newell
# 97    98                     Inception  2010     87  Christopher Nolan
# 98    99               American Beauty  1999     87         Sam Mendes
# 99   100                 Kung Fu Panda  2008     87     John Stevenson
#
#                                                  Cast  \
# 95  Kiana Madeira, Ashley Zukerman, Gillian Jacobs...
# 96  Al Pacino, Johnny Depp, Michael Madsen, Bruno ...
# 97  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...
# 98  Kevin Spacey, Annette Bening, Thora Birch, Wes...
# 99  Jack Black, Angelina Jolie, Jackie Chan, David...
#
#                                     Critics Consensus
# 95  Fear Street Part Three: 1666 sends the slasher...
# 96  A stark, nuanced portrait of life in organized...
# ...

# %%
movies.tail(10)
# Out:
#     Rank                   Movie Title  Year  Score           Director  \
# 90    91                     Paddleton  2019     89  Alexandre Lehmann
# 91    92                         Rango  2011     88     Gore Verbinski
# 92    93                  The Bad Guys  2022     88     Pierre Perifel
# 93    94                          Dope  2015     88      Rick Famuyiwa
# 94    95                        Oxygen  2021     88      Alexandre Aja
# 95    96  Fear Street Part Three: 1666  2021     88       Leigh Janiak
# 96    97                 Donnie Brasco  1997     88        Mike Newell
# 97    98                     Inception  2010     87  Christopher Nolan
# 98    99               American Beauty  1999     87         Sam Mendes
# 99   100                 Kung Fu Panda  2008     87     John Stevenson
#
#                                                  Cast  \
# 90  Mark Duplass, Ray Romano, Marguerite Moreau, C...
# 91  Johnny Depp, Isla Fisher, Abigail Breslin, Ned...
# ...

# %%
movies["Movie Title"].head()
# Out:
# 0                          His House
# 1           How to Train Your Dragon
# 2         The Forty-Year-Old Version
# 3                   Under the Shadow
# 4    Monty Python and the Holy Grail
# Name: Movie Title, dtype: object

# %%
movies[ 'Score'].head()
# Out:
# 0    100
# 1     99
# 2     99
# 3     99
# 4     98
# Name: Score, dtype: int64

# %%
movies[['Movie Title','Score']]
# Out:
#                         Movie Title  Score
# 0                         His House    100
# 1          How to Train Your Dragon     99
# 2        The Forty-Year-Old Version     99
# 3                  Under the Shadow     99
# 4   Monty Python and the Holy Grail     98
# ..                              ...    ...
# 95     Fear Street Part Three: 1666     88
# 96                    Donnie Brasco     88
# 97                        Inception     87
# 98                  American Beauty     87
# 99                    Kung Fu Panda     87
#
# [100 rows x 2 columns]

# %%
movies[['Movie Title','Score']].head()
# Out:
#                        Movie Title  Score
# 0                        His House    100
# 1         How to Train Your Dragon     99
# 2       The Forty-Year-Old Version     99
# 3                 Under the Shadow     99
# 4  Monty Python and the Holy Grail     98

# %%
movies[['Movie Title','Score']].tail(7)
# Out:
#                      Movie Title  Score
# 93                          Dope     88
# 94                        Oxygen     88
# 95  Fear Street Part Three: 1666     88
# 96                 Donnie Brasco     88
# 97                     Inception     87
# 98               American Beauty     87
# 99                 Kung Fu Panda     87

# %%
movies[['Movie Title','Score']].loc[5:10]
# Out:
#                   Movie Title  Score
# 5    Ma Rainey's Black Bottom     97
# 6             The Hurt Locker     97
# 7          Hell or High Water     97
# 8   Won't You Be My Neighbor?     97
# 9         Dolemite Is My Name     97
# 10  Hunt for the Wilderpeople     97

# %%
movies.drop()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-f51b6704fa26> in <cell line: 1>()
# ----> 1 movies.drop()
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...
